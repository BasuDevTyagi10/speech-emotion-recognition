# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Feature Extraction
# Data provided of audio cannot be understood by the models directly so we need to convert them into an understandable format for which feature extraction is used.
#
# In this project we will be extracting these features:
# - Zero Crossing Rate
# - Chroma_stft
# - MFCC
# - RMS(root mean square) value
# - MelSpectogram
#
# to train our model.

# %%
# Importing required packages
import pandas as pd
import numpy as np

import sys

import librosa

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
dataset = pd.read_csv("./data/dataset.csv")
dataset.head()
# Out:
#   Emotions                                               Path
# 0  neutral  ./data/Ravdess/audio_speech_actors_01-24/Actor...
# 1  neutral  ./data/Ravdess/audio_speech_actors_01-24/Actor...
# 2  neutral  ./data/Ravdess/audio_speech_actors_01-24/Actor...
# 3  neutral  ./data/Ravdess/audio_speech_actors_01-24/Actor...
# 4     calm  ./data/Ravdess/audio_speech_actors_01-24/Actor...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12162 entries, 0 to 12161
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Emotions  12162 non-null  object
#  1   Path      12162 non-null  object
# dtypes: object(2)
# memory usage: 190.2+ KB

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# %%
def extract_features(data, sample_rate):
    result = np.array([])
    # Zero Crossing Rate
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result = np.hstack((result, zcr))
    
    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # RMS(Root Mean Square) Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

# %%
def get_features_from_audio_file(path):
    # duration and offset are used to use important parts of the audio contributing to feature extraction
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data, sample_rate)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data, sample_rate)
    result = np.vstack((result, res2))
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch, sample_rate)
    result = np.vstack((result, res3))
    
    return result

# %%
X, Y = [], []
for i, (path, emotion) in enumerate(zip(dataset.Path, dataset.Emotions)):
    if(i%50 == 0):
        print(f"Completed: {i/dataset.shape[0]}%")
        print(f"Remaining Files: {dataset.shape[0] - i}")
    feature = get_features_from_audio_file(path)
    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)
# Out:
# Completed: 0.0%
# Remaining Files: 12162
# Completed: 0.0041111659266568%
# Remaining Files: 12112
# Completed: 0.0082223318533136%
# Remaining Files: 12062
# Completed: 0.0123334977799704%
# Remaining Files: 12012
# Completed: 0.0164446637066272%
# Remaining Files: 11962
# Completed: 0.020555829633284%
# Remaining Files: 11912
# Completed: 0.0246669955599408%
# Remaining Files: 11862
# Completed: 0.0287781614865976%
# Remaining Files: 11812
# Completed: 0.0328893274132544%
# Remaining Files: 11762
# Completed: 0.0370004933399112%
# Remaining Files: 11712
# Completed: 0.041111659266568%
# Remaining Files: 11662
# Completed: 0.0452228251932248%
# Remaining Files: 11612
# Completed: 0.0493339911198816%
# Remaining Files: 11562
# Completed: 0.0534451570465384%
# Remaining Files: 11512
# Completed: 0.0575563229731952%
# Remaining Files: 11462
# Completed: 0.061667488899852%
# Remaining Files: 11412
# Completed: 0.0657786548265088%
# Remaining Files: 11362
# Completed: 0.0698898207531656%
# Remaining Files: 11312
# Completed: 0.0740009866798224%
# Remaining Files: 11262
# Completed: 0.0781121526064792%
# Remaining Files: 11212
# Completed: 0.082223318533136%
# Remaining Files: 11162
# Completed: 0.0863344844597928%
# Remaining Files: 11112
# Completed: 0.0904456503864496%
# Remaining Files: 11062
# Completed: 0.0945568163131064%
# Remaining Files: 11012
# Completed: 0.0986679822397632%
# Remaining Files: 10962
# Completed: 0.10277914816642%
# Remaining Files: 10912
# Completed: 0.1068903140930768%
# Remaining Files: 10862
# Completed: 0.1110014800197336%
# Remaining Files: 10812
# Completed: 0.1151126459463904%
# Remaining Files: 10762
# Completed: 0.1192238118730472%
# Remaining Files: 10712
# Completed: 0.123334977799704%
# Remaining Files: 10662
# Completed: 0.1274461437263608%
# Remaining Files: 10612
# Completed: 0.1315573096530176%
# Remaining Files: 10562
# Completed: 0.1356684755796744%
# Remaining Files: 10512
# Completed: 0.1397796415063312%
# Remaining Files: 10462
# Completed: 0.143890807432988%
# Remaining Files: 10412
# Completed: 0.1480019733596448%
# Remaining Files: 10362
# Completed: 0.1521131392863016%
# Remaining Files: 10312
# Completed: 0.1562243052129584%
# Remaining Files: 10262
# Completed: 0.1603354711396152%
# Remaining Files: 10212
# Completed: 0.164446637066272%
# Remaining Files: 10162
# Completed: 0.1685578029929288%
# Remaining Files: 10112
# Completed: 0.1726689689195856%
# Remaining Files: 10062
# Completed: 0.1767801348462424%
# Remaining Files: 10012
# Completed: 0.1808913007728992%
# Remaining Files: 9962
# Completed: 0.185002466699556%
# Remaining Files: 9912
# Completed: 0.1891136326262128%
# Remaining Files: 9862
# Completed: 0.1932247985528696%
# Remaining Files: 9812
# Completed: 0.1973359644795264%
# Remaining Files: 9762
# Completed: 0.2014471304061832%
# Remaining Files: 9712
# Completed: 0.20555829633284%
# Remaining Files: 9662
# Completed: 0.20966946225949679%
# Remaining Files: 9612
# Completed: 0.2137806281861536%
# Remaining Files: 9562
# Completed: 0.2178917941128104%
# Remaining Files: 9512
# Completed: 0.2220029600394672%
# Remaining Files: 9462
# Completed: 0.22611412596612399%
# Remaining Files: 9412
# Completed: 0.2302252918927808%
# Remaining Files: 9362
# Completed: 0.2343364578194376%
# Remaining Files: 9312
# Completed: 0.2384476237460944%
# Remaining Files: 9262
# Completed: 0.24255878967275118%
# Remaining Files: 9212
# Completed: 0.246669955599408%
# Remaining Files: 9162
# Completed: 0.2507811215260648%
# Remaining Files: 9112
# Completed: 0.2548922874527216%
# Remaining Files: 9062
# Completed: 0.2590034533793784%
# Remaining Files: 9012
# Completed: 0.2631146193060352%
# Remaining Files: 8962
# Completed: 0.26722578523269197%
# Remaining Files: 8912
# Completed: 0.2713369511593488%
# Remaining Files: 8862
# Completed: 0.2754481170860056%
# Remaining Files: 8812
# Completed: 0.2795592830126624%
# Remaining Files: 8762
# Completed: 0.2836704489393192%
# Remaining Files: 8712
# Completed: 0.287781614865976%
# Remaining Files: 8662
# Completed: 0.2918927807926328%
# Remaining Files: 8612
# Completed: 0.2960039467192896%
# Remaining Files: 8562
# Completed: 0.30011511264594637%
# Remaining Files: 8512
# Completed: 0.3042262785726032%
# Remaining Files: 8462
# Completed: 0.30833744449926%
# Remaining Files: 8412
# Completed: 0.3124486104259168%
# Remaining Files: 8362
# Completed: 0.3165597763525736%
# Remaining Files: 8312
# Completed: 0.3206709422792304%
# Remaining Files: 8262
# Completed: 0.3247821082058872%
# Remaining Files: 8212
# Completed: 0.328893274132544%
# Remaining Files: 8162
# Completed: 0.33300444005920077%
# Remaining Files: 8112
# Completed: 0.3371156059858576%
# Remaining Files: 8062
# Completed: 0.3412267719125144%
# Remaining Files: 8012
# Completed: 0.3453379378391712%
# Remaining Files: 7962
# Completed: 0.349449103765828%
# Remaining Files: 7912
# Completed: 0.3535602696924848%
# Remaining Files: 7862
# Completed: 0.3576714356191416%
# Remaining Files: 7812
# Completed: 0.3617826015457984%
# Remaining Files: 7762
# Completed: 0.36589376747245517%
# Remaining Files: 7712
# Completed: 0.370004933399112%
# Remaining Files: 7662
# Completed: 0.3741160993257688%
# Remaining Files: 7612
# Completed: 0.3782272652524256%
# Remaining Files: 7562
# Completed: 0.3823384311790824%
# Remaining Files: 7512
# Completed: 0.3864495971057392%
# Remaining Files: 7462
# Completed: 0.390560763032396%
# Remaining Files: 7412
# Completed: 0.3946719289590528%
# Remaining Files: 7362
# Completed: 0.39878309488570957%
# Remaining Files: 7312
# Completed: 0.4028942608123664%
# Remaining Files: 7262
# Completed: 0.4070054267390232%
# Remaining Files: 7212
# Completed: 0.41111659266568%
# Remaining Files: 7162
# Completed: 0.4152277585923368%
# Remaining Files: 7112
# Completed: 0.41933892451899357%
# Remaining Files: 7062
# Completed: 0.4234500904456504%
# Remaining Files: 7012
# Completed: 0.4275612563723072%
# Remaining Files: 6962
# Completed: 0.43167242229896396%
# Remaining Files: 6912
# Completed: 0.4357835882256208%
# Remaining Files: 6862
# Completed: 0.4398947541522776%
# Remaining Files: 6812
# Completed: 0.4440059200789344%
# Remaining Files: 6762
# Completed: 0.4481170860055912%
# Remaining Files: 6712
# Completed: 0.45222825193224797%
# Remaining Files: 6662
# Completed: 0.4563394178589048%
# Remaining Files: 6612
# Completed: 0.4604505837855616%
# Remaining Files: 6562
# Completed: 0.46456174971221836%
# Remaining Files: 6512
# Completed: 0.4686729156388752%
# Remaining Files: 6462
# Completed: 0.472784081565532%
# Remaining Files: 6412
# Completed: 0.4768952474921888%
# Remaining Files: 6362
# Completed: 0.4810064134188456%
# Remaining Files: 6312
# Completed: 0.48511757934550237%
# Remaining Files: 6262
# Completed: 0.4892287452721592%
# Remaining Files: 6212
# Completed: 0.493339911198816%
# Remaining Files: 6162
# Completed: 0.49745107712547276%
# Remaining Files: 6112
# Completed: 0.5015622430521296%
# Remaining Files: 6062
# Completed: 0.5056734089787864%
# Remaining Files: 6012
# Completed: 0.5097845749054432%
# Remaining Files: 5962
# Completed: 0.5138957408321%
# Remaining Files: 5912
# Completed: 0.5180069067587568%
# Remaining Files: 5862
# Completed: 0.5221180726854135%
# Remaining Files: 5812
# Completed: 0.5262292386120704%
# Remaining Files: 5762
# Completed: 0.5303404045387272%
# Remaining Files: 5712
# Completed: 0.5344515704653839%
# Remaining Files: 5662
# Completed: 0.5385627363920408%
# Remaining Files: 5612
# Completed: 0.5426739023186976%
# Remaining Files: 5562
# Completed: 0.5467850682453543%
# Remaining Files: 5512
# Completed: 0.5508962341720112%
# Remaining Files: 5462
# Completed: 0.555007400098668%
# Remaining Files: 5412
# Completed: 0.5591185660253248%
# Remaining Files: 5362
# Completed: 0.5632297319519816%
# Remaining Files: 5312
# Completed: 0.5673408978786384%
# Remaining Files: 5262
# Completed: 0.5714520638052952%
# Remaining Files: 5212
# Completed: 0.575563229731952%
# Remaining Files: 5162
# Completed: 0.5796743956586088%
# Remaining Files: 5112
# Completed: 0.5837855615852656%
# Remaining Files: 5062
# Completed: 0.5878967275119223%
# Remaining Files: 5012
# Completed: 0.5920078934385792%
# Remaining Files: 4962
# Completed: 0.596119059365236%
# Remaining Files: 4912
# Completed: 0.6002302252918927%
# Remaining Files: 4862
# Completed: 0.6043413912185496%
# Remaining Files: 4812
# Completed: 0.6084525571452064%
# Remaining Files: 4762
# Completed: 0.6125637230718631%
# Remaining Files: 4712
# Completed: 0.61667488899852%
# Remaining Files: 4662
# Completed: 0.6207860549251768%
# Remaining Files: 4612
# Completed: 0.6248972208518336%
# Remaining Files: 4562
# Completed: 0.6290083867784904%
# Remaining Files: 4512
# Completed: 0.6331195527051472%
# Remaining Files: 4462
# Completed: 0.637230718631804%
# Remaining Files: 4412
# Completed: 0.6413418845584608%
# Remaining Files: 4362
# Completed: 0.6454530504851176%
# Remaining Files: 4312
# Completed: 0.6495642164117744%
# Remaining Files: 4262
# Completed: 0.6536753823384311%
# Remaining Files: 4212
# Completed: 0.657786548265088%
# Remaining Files: 4162
# Completed: 0.6618977141917448%
# Remaining Files: 4112
# Completed: 0.6660088801184015%
# Remaining Files: 4062
# Completed: 0.6701200460450584%
# Remaining Files: 4012
# Completed: 0.6742312119717152%
# Remaining Files: 3962
# Completed: 0.6783423778983719%
# Remaining Files: 3912
# Completed: 0.6824535438250288%
# Remaining Files: 3862
# Completed: 0.6865647097516856%
# Remaining Files: 3812
# Completed: 0.6906758756783424%
# Remaining Files: 3762
# Completed: 0.6947870416049992%
# Remaining Files: 3712
# Completed: 0.698898207531656%
# Remaining Files: 3662
# Completed: 0.7030093734583128%
# Remaining Files: 3612
# Completed: 0.7071205393849695%
# Remaining Files: 3562
# Completed: 0.7112317053116264%
# Remaining Files: 3512
# Completed: 0.7153428712382832%
# Remaining Files: 3462
# Completed: 0.7194540371649399%
# Remaining Files: 3412
# Completed: 0.7235652030915968%
# Remaining Files: 3362
# Completed: 0.7276763690182536%
# Remaining Files: 3312
# Completed: 0.7317875349449103%
# Remaining Files: 3262
# Completed: 0.7358987008715672%
# Remaining Files: 3212
# Completed: 0.740009866798224%
# Remaining Files: 3162
# Completed: 0.7441210327248807%
# Remaining Files: 3112
# Completed: 0.7482321986515376%
# Remaining Files: 3062
# Completed: 0.7523433645781944%
# Remaining Files: 3012
# Completed: 0.7564545305048512%
# Remaining Files: 2962
# Completed: 0.760565696431508%
# Remaining Files: 2912
# Completed: 0.7646768623581648%
# Remaining Files: 2862
# Completed: 0.7687880282848216%
# Remaining Files: 2812
# Completed: 0.7728991942114783%
# Remaining Files: 2762
# Completed: 0.7770103601381352%
# Remaining Files: 2712
# Completed: 0.781121526064792%
# Remaining Files: 2662
# Completed: 0.7852326919914487%
# Remaining Files: 2612
# Completed: 0.7893438579181056%
# Remaining Files: 2562
# Completed: 0.7934550238447624%
# Remaining Files: 2512
# Completed: 0.7975661897714191%
# Remaining Files: 2462
# Completed: 0.801677355698076%
# Remaining Files: 2412
# Completed: 0.8057885216247328%
# Remaining Files: 2362
# Completed: 0.8098996875513895%
# Remaining Files: 2312
# Completed: 0.8140108534780464%
# Remaining Files: 2262
# Completed: 0.8181220194047032%
# Remaining Files: 2212
# Completed: 0.82223318533136%
# Remaining Files: 2162
# Completed: 0.8263443512580168%
# Remaining Files: 2112
# Completed: 0.8304555171846736%
# Remaining Files: 2062
# Completed: 0.8345666831113304%
# Remaining Files: 2012
# Completed: 0.8386778490379871%
# Remaining Files: 1962
# Completed: 0.842789014964644%
# Remaining Files: 1912
# Completed: 0.8469001808913008%
# Remaining Files: 1862
# Completed: 0.8510113468179575%
# Remaining Files: 1812
# Completed: 0.8551225127446144%
# Remaining Files: 1762
# Completed: 0.8592336786712712%
# Remaining Files: 1712
# Completed: 0.8633448445979279%
# Remaining Files: 1662
# Completed: 0.8674560105245848%
# Remaining Files: 1612
# Completed: 0.8715671764512416%
# Remaining Files: 1562
# Completed: 0.8756783423778983%
# Remaining Files: 1512
# Completed: 0.8797895083045552%
# Remaining Files: 1462
# Completed: 0.883900674231212%
# Remaining Files: 1412
# Completed: 0.8880118401578688%
# Remaining Files: 1362
# Completed: 0.8921230060845255%
# Remaining Files: 1312
# Completed: 0.8962341720111824%
# Remaining Files: 1262
# Completed: 0.9003453379378392%
# Remaining Files: 1212
# Completed: 0.9044565038644959%
# Remaining Files: 1162
# Completed: 0.9085676697911528%
# Remaining Files: 1112
# Completed: 0.9126788357178096%
# Remaining Files: 1062
# Completed: 0.9167900016444663%
# Remaining Files: 1012
# Completed: 0.9209011675711232%
# Remaining Files: 962
# Completed: 0.92501233349778%
# Remaining Files: 912
# Completed: 0.9291234994244367%
# Remaining Files: 862
# Completed: 0.9332346653510936%
# Remaining Files: 812
# Completed: 0.9373458312777504%
# Remaining Files: 762
# Completed: 0.9414569972044071%
# Remaining Files: 712
# Completed: 0.945568163131064%
# Remaining Files: 662
# Completed: 0.9496793290577208%
# Remaining Files: 612
# Completed: 0.9537904949843776%
# Remaining Files: 562
# Completed: 0.9579016609110343%
# Remaining Files: 512
# Completed: 0.9620128268376912%
# Remaining Files: 462
# Completed: 0.966123992764348%
# Remaining Files: 412
# Completed: 0.9702351586910047%
# Remaining Files: 362
# Completed: 0.9743463246176616%
# Remaining Files: 312
# Completed: 0.9784574905443184%
# Remaining Files: 262
# Completed: 0.9825686564709751%
# Remaining Files: 212
# Completed: 0.986679822397632%
# Remaining Files: 162
# Completed: 0.9907909883242888%
# Remaining Files: 112
# Completed: 0.9949021542509455%
# Remaining Files: 62
# Completed: 0.9990133201776024%
# Remaining Files: 12

# %%
features_dataset = pd.DataFrame(X)
features_dataset['labels'] = Y
features_dataset.to_csv('./data/features_dataset.csv', index=False)
features_dataset.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.300781  0.732068  0.752591  0.733378  0.731624  0.704962  0.662388
# 1  0.335006  0.783609  0.838017  0.829405  0.825558  0.824765  0.757258
# 2  0.185847  0.622753  0.718277  0.747283  0.709554  0.688333  0.674101
# 3  0.271272  0.674888  0.723125  0.724594  0.681155  0.670361  0.674336
# 4  0.313300  0.775134  0.813024  0.795702  0.780789  0.785470  0.700858
#
#           7         8         9  ...           153           154  \
# 0  0.687283  0.735435  0.756200  ...  4.319258e-06  3.298864e-06
# 1  0.694166  0.734845  0.763651  ...  1.252698e-04  1.222288e-04
# 2  0.661235  0.697782  0.739232  ...  8.620835e-07  9.594722e-07
# 3  0.629854  0.680085  0.708237  ...  6.998011e-06  7.050108e-06
# 4  0.654817  0.712211  0.741578  ...  6.885124e-05  6.948706e-05
#
#             155           156           157           158       159  \
# 0  2.153281e-06  2.286675e-06  5.131692e-06  8.065742e-06  0.000005
# 1  1.163826e-04  1.182331e-04  1.225794e-04  1.164659e-04  0.000122
# 2  7.775631e-07  5.270748e-07  3.628429e-07  9.075997e-07  0.000001
# 3  6.670962e-06  6.999257e-06  1.217880e-05  9.449916e-06  0.000008
# 4  6.912925e-05  6.853575e-05  7.073970e-05  6.978575e-05  0.000069
#
#             160           161   labels
# 0  2.270857e-06  1.642365e-07  neutral
# 1  1.236960e-04  1.197713e-04  neutral
# 2  5.035564e-07  2.570757e-08  neutral
# 3  2.638513e-06  1.788902e-07  neutral
# 4  6.273952e-05  6.125250e-05  neutral
#
# [5 rows x 163 columns]
